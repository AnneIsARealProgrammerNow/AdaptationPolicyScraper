# %%
import requests
import lxml

# %%
response = requests.get("https://opendata.rijksoverheid.nl/v1/infotypes/news?output=xml&rows=200&offset=1&title='klimaatverandering'")
print(len(response.text))
response.text
# Out:
# 202067

# %%
response = requests.get("https://opendata.rijksoverheid.nl/v1/documents?subType=Kamervragen")
print(len(response.text))
response.text
# Out:
# 20357
# ...

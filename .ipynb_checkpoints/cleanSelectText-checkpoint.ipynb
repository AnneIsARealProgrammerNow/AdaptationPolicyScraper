# %%
from nltk.tokenize import sent_tokenize
from nltk.corpus import stopwords
from bs4 import BeautifulSoup as bs

#from langdetect import detect
import os
import csv
import re
import string
import pickle

import pandas as pd

import time

# %%
#import nltk

#nltk.download('stopwords')
#nltk.download('punkt')

# %% [markdown]
# To clean the texts, here are some useful functions

# %%
class BasePreProcessor:
    language_map = {'en': 'english', 'es': 'spanish', 'fr': 'french', 'ru': 'russian', 'ar': 'arabic'}
    stop_words = set(stopwords.words('english'))

    def __init__(self):
        self.language_count = {}
        # Keep a record of links to check & nr removed for having too-few and too-many
        self.to_check = []
        self.too_few = 0
        self.too_many = 0

    def preprocess(self, file_path, html = 'auto'):
        
        assert os.path.splitext(file_path)[1] == '.txt', f"{file_paht}: pre-processing assumes .txt input"
        
        #Open the txt file
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()
        
        #Skip empty (often scans or images only)
        if len(text) == 0:
            return(None)
        
        #Check if text contains HTML -- if so/set to True, strip to only headings, paragraphs and lists
        if html == True or (html == 'auto' and bool(bs(text, "lxml").find())):
            text =  self.text_from_html(text, file_path)
            
        
        #Process the text
        sentence_list = self.process_string(text)
        
        #We can set a minimum/maximum number of sentences; ignore for now
        # if SENTENCES_PER_PAGE_MIN <= len(sentence_list) < SENTENCES_PER_PAGE_MAX:
        #     page_dict[page] = sentence_list
        # elif len(sentence_list) < SENTENCES_PER_PAGE_MIN:
        #     self.too_few += 1
        # elif len(sentence_list) >= SENTENCES_PER_PAGE_MIN:
        #     self.too_many += 1
            
        return sentence_list
    
    def text_from_html(self, html_text, file_path):
        soup = bs(html_text)
        #Many pages (incl. most news items) have their main text in one div
        texts = [t.text for t in soup.find_all("div", {"data-module": "govspeak"})]
        texts = " ".join(texts)
        
        #Otherwise, take paragraphs, headings, lists on page
        if len(texts)>30:
            return(texts)
        else:
            #print(f"No govspeak for {file_path}")
            texts = [x.text for x in soup.find_all(['p', 'h1', 'h2', 'h3', 'li', 'ol', 'ul'])]

            #Remove header and footer. 
            #Some pages have a non-standard layout but it seems many end their header with the same line
            try:
                head_index = texts.index('\n  Where we have identified any third party copyright information you will need to obtain permission from the copyright holders concerned.\n')
                if texts[head_index+1].startswith('\n  This publication is available at'):
                    texts = texts[head_index+2:]
                else:
                    texts = texts[head_index+1:]
            except ValueError as e:
                self.to_check.append((file_path, e))
                #print(f'No header found for {file_path}', flush=True)
            #Similarly, pages by default end with a "is this page useful?" button
            try:
                foot_index = texts.index('Is this page useful?')
                texts = texts[:foot_index]
            except ValueError as e:
                self.to_check.append((file_path, e))
                #print(f'No footer found for {file_path} - {e}', flush = True)
                
            return(" ".join(texts))

    def process_string(self, messy_text, 
                       MULTIPLE_PUNCTUATION = 4, 
                      SENTENCE_MIN_CHARACTERS = 3, SENTENCE_MIN_WORDS = 1,
                       SENTENCE_MAX_WORDS = False
                      ):
        """ Tokenize on sentence level and do some basic filtering:
            - Replace newline characters with a space
            - Remove URLs, remove e-mail addresses.
            - Attempts to remove table of contents by filtering lines with many multiples of dots and white spaces (e.g. 1.csv).
            - Remove lines with at least half of characters as numerics/punctuation (helps with table of contents)
            - Remove too short/too long sentences (may help with tables)
            - Lowercase everything
            This function can be sped up, but let's keep it uncomplicated.
            The downsides of such simple pre-processing are:
            - Sentences may be cut in two, or joined by sentences from captions.
            - Title pages, tables of contents, lists of tables and figures are generally difficult to filter out.
            - The sentence tokenizer is not able to deal with errors from the PDF parser.
            - Cannot filter out addresses.
        """
        # == General text-based pre-processing ==
        # Replace hyphens with spaces.
        messy_text = messy_text.replace('- ', '-')
        # Remove urls, e-mail, newline characters (both windows & mac format)
        messy_text = re.sub(r'http\S+', '', messy_text)
        messy_text = re.sub(r'\S+@\S+(?:\.\S+)+', '', messy_text)
        messy_text = re.sub(r'\r\n|\r|\n', ' ', messy_text)
        
        # == Sentence-based filtering ==
        # Use NLTK to tokenize sentences. Assumes all texts are English
        tokenized_sentences = sent_tokenize(messy_text, language='english')
        
        # Attempts to remove tables of contents, if white space or dots occurs more than MULTIPLE_PUNCTUATION.
        dot_str, space_str = '.' * MULTIPLE_PUNCTUATION, ' ' * MULTIPLE_PUNCTUATION
        tokenized_sentences = [sentence for sentence in tokenized_sentences
                               if (dot_str not in sentence and space_str not in sentence)]
        
        # Remove sentences if more than half the sentence is numeric.
        tokenized_sentences = [sentence for sentence in tokenized_sentences if len(sentence) > 0]
        tokenized_sentences = [sentence for sentence in tokenized_sentences
                               if (len(''.join(re.findall(r'\d+', sentence))) / len(sentence)) < 0.5]
        
        # Remove short and long sentences (long can become important if we want to do  embeddings)
        tokenized_sentences = [sentence for sentence in tokenized_sentences
                               if (len(sentence) >= SENTENCE_MIN_CHARACTERS and len(sentence.split()) >= SENTENCE_MIN_WORDS)]
        if SENTENCE_MAX_WORDS:
            tokenized_sentences = [sentence for sentence in tokenized_sentences if len(sentence.split()) < SENTENCE_MAX_WORDS]
        
        # # Remove all caps sentences.
        # tokenized_sentences = [sentence for sentence in tokenized_sentences if not sentence.isupper()]
        
        #Lowercase each sentence
        tokenized_sentences = [s.lower() for s in tokenized_sentences]
        
        #For creating the initial database, let's just return the text as one long string
        #Depending on if we choose to select by sentence or by word count or..., this may change
        return(" ".join(tokenized_sentences))

    def tokenized_preprocess(self, page_dict, language): #OLD- processes on word level; I don't think we'll need this
        for page_id, text in page_dict.items():
            # Join the string by a space.
            text = ' '.join(text)
            # Remove all numeric characters.
            non_numeric_text = ''.join(i for i in text if not i.isdigit())
            # remove punctuation.
            non_numeric_text = non_numeric_text.translate(str.maketrans('', '', string.punctuation))
            # Remove stop words.
            language_stopwords = set(stopwords.words(language))
            filtered_words = [word for word in non_numeric_text.split()
                              if word not in language_stopwords and len(word) > 2]
            stripped_sentence = ' '.join(filtered_words)
            page_dict[page_id] = stripped_sentence
        return page_dict

# %%
#Let's try this on our test folder
t0 = time.time()
#file_path = r'D:\OneDrive - Wageningen University & Research\Policy scraper UK NL\Data\Test\test_html.txt'
file_dir = r'C:\Users\siets009\OneDrive - Wageningen University & Research\Policy scraper UK NL\Data\TestOut'

processor = BasePreProcessor()

out = []
for i, file in enumerate(os.listdir(file_dir)):
    if file.endswith('.txt'):
        out.append(processor.preprocess(os.path.join(file_dir, file)))
        print(i, file)
            

print('\n', f"Processed {len(out)} texts in {int(time.time() - t0)} seconds")
out[:5]
# Out:
# 0 002.21_-_Land_at_Pines_Hill_-_Design_and_Access_Statement-compressed_Redacted.txt
# 1 03335-CO-Integrated-Review-Foreward-and-Overview-FINAL-RUSSIAN-WEB-DISPLAYABLE-PDF.txt
# 2 03335-CO-Integrated-Review-Foreword-and-Overview-FINAL-ARABIC-WEB-DISPLAYABLE-PDF.txt
# 3 03335-CO-Integrated-Review-Foreword-and-Overview-FINAL-CHINESE-WEB-DISPLAYABLE-PDF.txt
# 4 03335-CO-Integrated-Review-Foreword-and-Overview-FINAL-FRENCH-WEB-DISPLAYABLE-PDF.txt
# 5 03335-CO-Integrated-Review-Foreword-and-Overview-FINAL-SPANISH-WEB-DISPLAYABLE-PDF.txt
# 6 0342.txt
# 7 1-public-evidence-session-9-july-2013.txt
# 8 1-s2.0-S1876610214023558-main.txt
# 9 13-809-future-manufacturing-project-report.txt
# 10 13_1574.txt
# 11 143-foi-12-0449-0450--environmental-information-regul.txt
# 12 14_0483.txt
# 13 14_0639.txt
# 14 151209_publication_v1_4.txt
# 15 1943-nps-nuclear-power-annex-volII.txt
# 16 2014_15241.txt
# 17 2014_15314.txt
# 18 2018-final-emissions-statistics-summary.txt
# 19 2018_EASO_COI_Nigeria_TargetingIndividuals.txt
# 20 2018_Final_greenhouse_gas_emissions_statistical_release.txt
# 21 2019-05-Listeria-CC8-Outbreak-Report.txt
# 22 2019-TCFD-Status-Report-FINAL-0531191.txt
# 23 2019_Final_emissions_statistics_one_page_summary.txt
# 24 2019_Final_greenhouse_gas_emissions_statistical_release.txt
# 25 2021-Metrics_Targets_Guidance-1.txt
# 26 2021-TCFD-Implementing_Guidance.txt
# 27 20210331_-_CRED_Report_-_FINAL_-_Web_Accessible.txt
# 28 20210407_-_CRED__report_-_Large_Print.txt
# 29 2021_07_EASO_COI_Report_Syria_Security_situation.txt
# 30 2023-green-finance-strategy-annexes.txt
# 31 21064_WL_Human_Rights_Annual_Report_High_Res.txt
# 32 2901304_CMO_complete_low_res_accessible.txt
# 33 6339-consultation-on-biomass-electricity--combined-hea.txt
# 34 7050-discussion-paper-deforestation-event.txt
# 35 AHRR_2014_Final_to_TSO.txt
# 36 Annex_1_The_Charity_Commissions_approach_to_tackling_abuse___mismanagement.txt
# 37 Annex_2_Glossary_types_of_compliance_case_work.txt
# 38 Annex_3_Statistical_analysis.txt
# 39 Campaigning_and_political_issues_arising_in_the_runup_to_the_2015_General_Election.txt
# 40 ccus-dpa-standard-terms-and-conditions-november-2022.txt
# 41 CLEAN_UKs_8th_National_Communication__20_.txt
# 42 C_Ewing_-_Appendices_-_All_Combined_Redacted.txt
# 43 Draft_DPA_Terms_and_Conditions__April_2022_.txt
# 44 Effects_on_UK_immigration_through_gobal_warming_FOI_Ref_0604-14.txt
# 45 Energy_and_Sustanability_Statement_Redacted.txt
# 46 EU_REACH_Regulations_1907_2006__1_.txt
# 47 fawcopiniononthewelfareofanimalsduringtransport.txt
# 48 FCDO_annual_report_and_accounts_2020_to_2021_accessible.txt
# 49 fourth-uk-joint-convention-report.txt
# 50 FRS-102-WEB-Ready-2015.txt
# 51 gene0910bsrx-e-e.txt
# 52 generic_cfd_t_and_cs.txt
# 53 HMRC_Annual_Report_and_Accounts_2021_to_2022_Print.txt
# 54 Industrial_Carbon_Capture_Standard_Terms_and_Conditions.txt
# 55 Industrial_Carbon_Capture_Standard_Terms_and_Conditions__Annex_A__April_2022.txt
# 56 Inspector_s_Report_Feb_2004_Redacted.txt
# 57 Key_figures_from_our_compliance_case_work_in_2014-15.txt
# 59 mission-zero-independent-review.txt
# 60 Monetary-Valuation-of-Risks-and-Opportunities-in-CCRA3.txt
# 61 ngs-guidance.txt
# 62 nts_volume_17_br_ethology_animal_behaviour_biology.txt
# 63 OESEA2_ER_with_NTS_Part2.txt
# 64 OES_A3j_Conservation.txt
# 65 OES_Environmental_Report.txt
# 66 pb13837-aqeg-fine-particle-matter-20121220.txt
# 67 pub5199.txt
# 68 re-appointments-to-the-environment-agency.txt
# 69 reading-university-head-of-the-river-race-2022-river-closure-notice.txt
# 70 reading-water-fest-2022-river-closure-notice.txt
# 71 readout-foreign-secretary-call-with-us-secretary-of-state-antony-blinken.txt
# 72 readout-from-foreign-secretary-meeting-with-foreign-minister-kang-of-south-korea-in-seoul.txt
# 73 readout-from-meeting-between-cop26-president-designate-alok-sharma-and-prime-minister-yoshihide-suga-of-japan.txt
# 74 readout-of-international-trade-secretary-liz-truss-call-with-ustr-katherine-tai.txt
# 75 readout-of-international-trade-secretary-meeting-with-us-trade-representative.txt
# 76 readout-of-meeting-between-dit-and-dcms-secretaries-of-state-and-us-commerce-secretary.txt
# 77 realising-our-potential-a-strategy-for-science-engineering-and-technology.txt
# 78 reappointment-of-chief-executive-for-the-natural-environment-research-council.txt
# 79 reappointment-of-chief-executive-of-the-science-and-technology-facilities-council-for-2015-to-2019.txt
# 80 reappointment-of-science-and-technology-facilities-council-chair.txt
# 81 reappointment-of-the-members-of-the-nuclear-liabilities-financing-assurance-board.txt
# 82 reappointment-to-the-adaptation-committee-of-the-climate-change-committee.txt
# 83 rear-admiral-morisetti-the-uk-s-climate-and-energy-security-envoy-visits-new-york.txt
# 84 reassurance-to-land-managers-to-plant-trees-now.txt
# 85 rebuilding-a-resilient-britain-summary-report.txt
# 86 recalculation-of-redundancy-related-claims-to-be-carried-out.txt
# 87 recent-trends-in-mortality-in-england-review-and-data-packs.txt
# 88 reckitt-announced-as-principal-partner-for-cop26-climate-summit-in-glasgow.txt
# 89 recognised-stock-exchanges-section-1005-income-tax-act-2007.txt
# 90 srpew_final_report.txt
# 91 Statement-Presumption_5yr_HLS-Feb_23_Redacted.txt
# 92 Stiglitz-Sen-Fitoussi-Commission-report.txt
# 93 strategic-fit-updated-gdpgva-impacts.txt
# 94 Tackling_abuse_and_mismanagement_PDF_master_web.txt
# 95 TAM_Foreword.txt
# 96 Technical-report-on-the-COVID-19-pandemic-in-the-UK-PRINT.txt
# 97 Thames-FRMP-2021-2027.txt
# 98 the_tax_code_of_the_rk_2015.txt
# 99 UK-Voluntary-National-Review-2019.txt
# 100 UKTI_Inward_Investment_Report_2013-2014.txt
# 101 UKVNR-web-accessible1.txt
#
#  Processed 101 texts in 140 seconds
# ["l a n d e a s t o f p i n e s h i l l stansted mountfitchet design and access statement february 2023 land east of pines hill, stansted mountfitchet:design and access statement this design and access statement has been prepared by on architecture on behalf of luxus homes ltd. this document has been designed to be printed double sided at a3 (landscape). logan house, first published by on architecture ltd, august 2021. st andrews close, canterbury, © 2021 on architecture ltd (unless otherwise stated within this document) prepared by elm / tw ct1 2rp all rights reserved. no part of this publication may be reproduced, stored in retrieval systems, or transmitted, in any form or by any checked by jr means electronic, mechanical, photocopying, recording or otherwise without prior permission of on architecture ltd. t:01227 634 334 date issued february 2023  please note: revision - w: unless otherwise stated all drawings, maps, images and diagrams contained within this document are not to scale. contents land east of pines hill, stansted mountfitchet design and access statement 01 introduction 02 assessment physical nature and character of area 7 contextual study 9 heritage statement 10 local amenities and sustainability credentials 12 history of the site 13 urban grain comparison 15 03 evaluation opportunities and constraints 17 04 design land use 19 access and movement 20 density 21 building heights 22 design principles 23 illustrative layout 26 illustrative site layout in the wider context 27 indicative schedule of accommodation 28 access 29 sustainable design 30 precedent images 31 05 conclusion 01 land east of pines hill introduction 01 introduction on architecture have been appointed to consider the potential for development the site is surrounded by various local amenities and transport links, motorway at land east of pines hill, stansted mountfitchet. this design and access these include the m11 which provides routes to london from the south and statement accompanies an outline application for up to 31 dwellings, with all cambridge from the north. the site is also a 10 minute walk to stansted main access roads to site matters reserved for subsequent approval apart from vehicular access onto mountfitchet station allowing links to london liverpool street and cambridge pines hill. north stations. pines hill (b1383) situated to the west to the site also provides train line local links to newport in the north and bishops storford to the south. train station this document sets out the background to the project and summarises the design process and considerations that have been taken into account in developing the illustrative site layout and design principles that can be achieved on the site. to newport to cambridge to cambridge north stanstead mountfitchet stansted mountfitchet station site 3)831b ( hill s enpi m11 london stansted airport bishops storford to london to bishops to london liverpool street storford 5 land east of pines hill, stansted mountfitchet:design and access statement 02 land at the east of pines hill assessment 02 assessment physical nature and character of area esolc the proposed site is located within stansted mountfitchet and is bounded by l l pscioitnerne beso h inllid t hao tythh eleie wsa e ialwsnta aayrn elidna so t bfo elnayenoydn c da.no rdm ecmsooimdnem retoiraacl diap lrt o pstheeer ione o r teihe .s tooou ththhe-ee aeosuat s te rn broome be old ,u r ou tt sth end care r w t r e n l t t s t h home western, northern and north western boundaries of the site. the existing site is currently disused land which is characterised by vegetation stoney apnrodp ae rntiuems, blaerrg oef mtreaenso.r thhoeu sseusrr,o cuanrdei nhgo mareesa acnodn tcaoinmsm ae mrciixatlu prere omf irseessid.ential common road the site is located at the edge of a large development to the north and east on old bell close, which comprises the village of stansted mountfitchet. the site also provides local access to stansted airport whic ...
#  'глобальная британия в эпоху конкуренции комплексная стратегия по вопросам обороны, дипломатии и международного развития i. предисловие премьер-министра когда мы приступали к работе над комплексной стратегией в начале 2020 года, мы не могли предвидеть, что коронавирус спровоцирует, по всей видимости, крупнейший международный кризис со времён второй мировой войны, трагические последствия которого будут ощущаться ещё долгие годы. covid-19 напомнил нам о том, что угрозы безопасности и испытания устойчивости государств могут принимать разные формы. благодаря стойкости британского народа и титаническим усилиям нашей национальной службы здравоохранения, великобритания преодолевает пандемию с вновь обретённой решимостью и оптимизмом. наш путь к восстановлению уже начался, и мы полны решимости восстановить всё по принципу лучше, чем было, чтобы стать ещё более сильной, безопасной и процветающей страной, чем раньше. вместе с тем, если мы хотим избежать губительных последствий распространения вируса, оперативная вакцинация, а значит и защита людей не должна прекращаться у национальных границ. поэтому великобритания объединила усилия с другими странами в рамках инициативы covax для проведения кампании вакцинации по всему миру. с выходом из европейского союза началась новая глава нашей истории. имея глобальную сеть друзей и партнёров и возможности для налаживания новых и более глубоких отношений, мы будем открыты миру и сможем свободно проложить свой собственный путь. соглашение о торговле и сотрудничестве с ес даёт нам возможность выбрать иной, лучший путь развития — как в экономике, так и в политике. в предстоящие годы благодаря способности адаптироваться и действовать оперативно мы сможем приносить ещё больше пользы нашим гражданам, обеспечивая процветание и безопасность страны. моё видение того, какой великобритания будет к 2030 году, задаёт амбициозные цели, которых может достичь наша страна. союз между англией, шотландией, уэльсом и северной ирландией снова и снова доказывает свои преимущества, в том числе в борьбе с пандемией. это важнейший источник сил для нашего успеха как внутри страны, так и за рубежом. наша страна богата талантами в сферах искусства и науки, благодаря которым «мягкая сила» распространяется по планете. немного стран находятся в лучшем положении для того, чтобы успешно справляться с вызовами, которые будут вставать перед нами в будущем, однако мы должны быть готовы к тому, что нам потребуется изменить подход и адаптироваться к новому миру, который рождается вокруг нас. открытые демократические общества, такие как великобритания, должны показать, что они способны добиться успеха в более конкурентом мире. нам нужно демонстрировать, что свобода слова, мысли и выбора — и, следовательно, свобода инноваций — дают обществу преимущества, и что либеральная демократия и свободный рынок остаются наилучшей моделью для достижения социального и экономического прогресса человечества. история доказывает, что демократические общества являются самыми решительными сторонниками открытого и устойчивого международного порядка, в котором международные организации демонстрируют свою способность защищать права человека, снижать напряженность между великими державами, урегулировать конфликты, решать проблемы нестабильности и изменения климата и распределять блага процветания с помощью торговли и инвестиций. такой открытый и устойчивый международный порядок, в свою очередь, является лучшей гарантией безопасности наших граждан. i. предисловие премьер-министра 3 открытость требует обеспечения безопасности. защита своего народа, родины и демократии — первостепенная обязанность любого правительства, поэтому я запустил реализацию крупнейшей программы инвестиций в оборону со времён окончания холодной войны. это продемонстрирует нашим союзникам в европе и за её пределами, что они всегда могут рассчитывать на помощь великобритании, если она будет необходима. мы взяли на себя ещё более высокие обязательства в сфере оборонных расходов, чем те, что ...
#  'ةيملاعلا ايناطيرب سفانتلا رصع يف عافدلاو نملأل ةلماكتملا ةعجارملا ةيجراخلا ةسايسلاو ةيمنتلاو ءارزولا سيئر نم ديهمت .1 نكي مل ،2020 علطم يف ةلماكتملا ةعجارملا دادعإب انأدب امدنع ةمزأ يف ببستيس انوروك سوريف نأ كاذنيح عقوتن نأ انناكمإب هتفلخ ام عم ،ةيناثلا ةيملاعلا برحلا ذنم ربكلأا يه نوكت دق ةيملاع ةحئاج انل ترهظأ دقو .ةمداق تاونسل رمتستس ةيثراك جئاتن نم دومصلا ىلع ةينطولا انتردق ناحتماو اننملأ ديدهتلا نأب 19-ديفوك .ةددعتم لااكشأ اذخأي نأ نكمي يتلا ةرابجلا دوهجلاو ،يناطيربلا بعشلا لمحت ةوق لضفب نكل نم ةدحتملا ةكلمملا ضهنت ،ةيحصلا ةياعرلل ةينطولا ةئيهلا اهتلذب ىلع انتلحر لاعف تأدب دقو .نيديدج لؤافتو ميمصتب ةحئاجلا هذه نامضل ،لضفأ لكشب ضوهنلا ىلع نومزاع نحنو ،يفاعتلا برد نأ اندرأ اذإ هنأ ريغ .لبق امم اراهدزاو ةملاس رثكأو ىوقأ نوكن نأ رصحني لاأ بجي سانلا ةيامحو ميعطت لجأ نم بوؤدلا لمعلا نإف ،سوريفلا اذهل ةراضلا راثلآا نم وجنن يف لودلا نم اهريغ ىلإ ةدحتملا ةكلمملا تمضنا ،قلطنملا اذه نمو .لودلل ةينطولا دودحلا قاطن نمض .ملاعلا ءاحنأ يف هذه تاميعطتلا ةلمح رشن لجأ نم )covax( سكافوك ةردابم نوكنس ثيح .اهخيرات نم اديدج لاصف تلخد دق ،يبورولأا داحتلاا نم اهجورخب ،ةدحتملا ةكلمملا نإ ءاقدصلأا نم ةيملاع ةكبشب معنن نحنو ،هيلع ريسنس يذلا بردلا رايتخا يف ارارحأو ،ملاعلا ىلع نيحتفنم داحتلاا عم نواعتلاو ةراجتلا ةيقافتاو .اقمع رثكأو ةديدج تاقلاع ةماقلإ انل ةحاتملا ةصرفلابو ،ءاكرشلاو .يسايسلاو يداصتقلاا نيديعصلا ىلع ،لضفأو فلتخم لكشب كرحتن نأب ةيرحلا انل حيتت يبورولأا .اننمأو انراهدزا زيزعتو ،انينطاوم ةمدخ نم ،كرحتلا يف انتعرس لضفب ،ةمداقلا تاونسلا يف نكمتنسو داحتا تبثأ دقلو .هققحت نأ اندلابل نكمي امل ةيلاع تاحومط مسرت 2030 ةنس يف ةدحتملا ةكلمملل يتيؤرو .ةحئاجلا هذه للاخ كلذ يف امب ،ىرخلأا ولت ةرم هتيمهأ ةيلامشلا ادنلريإو زليوو ادنلتكساو ارتلجنإ ةقلاخلا تاردقلاب ضيفت اندلاب نإ .جراخلا يف وأ لخادلا يف ءاوس ،انتوقل ردصم ربكأ داحتلاا اذه دّعيُو ءاجرأ ةفاك يف رشتنت يتلا ةديرفلا ةمعانلا انتوقل ةينغ رداصم ربتعت يتلاو ،مولعلاو نونفلا لاجم يف .ةرومعملا دادعتسا ىلع نوكن نأ انيلع نيعتي نكل ،انهجاوت يتلا تايدحتلا عم لماعتلل لضفأ ةناكم يف لود دجوت املق ةيطارقوميدلا تاعمتجملا ىلع يغبني .انلوح نم قثبني يذلا ديدجلا ملاعلا عم ملقأتلاو انتبراقم رييغتل راهظإ انيلع بجوتيسو .ةيسفانت رثكأ ملاع عم شياعتلل ةلهؤم اهنأ تبثت نأ ةدحتملا ةكلمملاك ةحتفنملاو ةيلاربيللا ةيطارقوميدلا نأو ؛ةليصأ ةزيم لكشت – راكتبلاا يلاتلابو – رايتخلااو ريكفتلاو ريبعتلا ةيرح نأ .رشبلا ةفاكل يداصتقلااو يعامتجلاا مدقتلا قيقحتل لثملأا جذومنلا لظت ةرحلا قاوسلأاو ،دومصلا ىلع رداقو حتفنم يملاع ماظنل معاد ىوقأ يه ةيطارقميدلا تاعمتجملا نأ خيراتلا تبثأ دقل نيب تارتوتلا ةرادإو ،ناسنلإا قوقح ةيامح ىلع اهتردق تبثتُ نأ هلظ يف ةيملاعلا تاسسؤملا عيطتست للاخ نم راهدزلاا رشنت نأو ،خانملا ريغتو رارقتسلاا مدع تلااحو تاعارصلا ةجلاعمو ،ىربكلا ىوقلا نملأ نماض لضفأ هرودب وه دومصلا ىلع رداقلاو حتفنملا يملاعلا ماظنلا كلذو .رامثتسلااو ةراجتلا .ةدحتملا ةكلمملا يف انينطاوم 3 ءارزولا سيئر نم ديهمت 1 انتيطارقميدو اننطوو انبعش ةيامح نإف يلاتلابو .ناملأا انل رفوتي نأ اضيأ دب لا ،نيحتفنم نوكن يكلو ،ةدرابلا برحلا ةياهن ذنم عافدلا يف رامثتسلال جمانرب مخضأ تُقلطأ اذل .ةموكح ةيأ ىلع بجاو لوأ يه .دئادشلا يف ةدحتملا ةكلمملا ىلع دامتعلاا امود مهناكمإب نأ اهجراخو ابوروأ يف انئافلحل رهظيُ ام وهو يركسعلا انقافنإ نأ املع ،وتانلا فلح هاجتو يباختنلاا اننايب بجومب قافنلإا يف انمازتلا زواجتن فوسو ةديدجلا تلااجملا لمشي ثيدحت جمانرب يف امدق يضمن فوسو .يلحملا جتانلا يلامجإ نم %2.2 نلآا غلبي عافدلا يف رمتسنس امك .ةروطتملا ايجولونكتلاب ةحلسملا انتاوق زيهجتو ،ءاضفلاو ينورتكللإا نملأا لثم ريغ ليومت لكش ىلع كلت تناك ءاوس ،ىرخلأا لودلا نم تاديدهتلا هجو يف انتمأ ةدحوو ةملاس نع نأشلا يف لخدت وأ ،ةينورتكلإ تامجه وأ ،ةللضم تامولعم ةلمح وأ ،ةيرسق ةيداصتقا ريبادت وأ ،عورشم ثدح يلع ءادتعلااك – لماشلا رامدلا ةحلسأ نم اهريغو ةيئايميكلا ةحلسلأا مادختسا ىتح وأ ،يباختنلاا .تاونس ثلاث لبق يروبزلاس يف يف يباهرلإا ديدهتلا نإف ،غنديرو ندنلو رتسشنام يف فسلأل تعقو يتلا تاءادتعلاا ترهظأ امكو ادنلريإب اطبترم وأ ،ةيوملاسإ ةيجولويديأ ىلإ دنتسي ناك ءاوس -اقيقح اديدهت امئاد لظي ةدحتملا ةكلمملا ىلع لمعت نوناقلا قيبطت ةزهجأو ةيتارابختسلااو ةينملأا انتزهجأو .ىرخأ تاياغب اعوفدم وأ ،ةيلامشلا .2017 ذنم اربدمُ اموجه 28 طابحإ نم تنكمت دقو ،مهدح دنع نيلمتحملا نييباهرلإا فقول ةعاسلا رادم ...
#  '竞争时代的“全球化英国” 《安全、国防、发展和外交政策整合评估》 i. 首相序言 2020 年年初，当我们开始进行《整合评估》时，我们 不可能预料到一种冠状病毒将如何引发或许是二战以 来最大的国际危机，其悲惨的后果将持续多年。2019 年的新冠提醒我们，安全威胁和对国家韧性的考验可以 有多种形式。 感谢英国人民不屈不挠，感谢英国国民医疗服务体系的 巨大努力，英国正重整旗鼓，乐观地从这场全球大流行 中摆脱出来。我们已踏上复兴之路，我们决心更好地重 建，确保英国比以前更加强大、更加安全、更加繁荣。 如果我们要摆脱新冠病毒的不良影响，那么为民众接种 疫苗从而保护民众的这场竞赛就不能止步于国界。因此，英国已与各国一道加入获取 新冠疫苗全球采购机制（英文缩写 covax）的倡议，在全球范围内扩大这一举措的 范围。 英国已经脱离欧盟，开启了历史的新篇章。我们将向全球开放，自由地走自己的路。我 们有幸拥有由盟友与伙伴组成的全球网络，有机会建立全新的、更深入的关系。我们 与欧盟签署的《英欧贸易与合作协议》赋予了我们自由，无论在经济上还是在政治上， 我们都能以不同的方式行事，并做得更好。在未来的岁月里，敏捷度和行动速度将使 我们能够为英国公民切实交付，促进繁荣，提升安全。 我对英国 2030 年的愿景为我们国家可以取得的成就设定了很高的目标。英格兰、苏 格兰、威尔士以及北爱尔兰组成的联合王国，无数次地证明了其价值，在此次全球大流 行病期间也是如此。无论是在国内还是国外，四大区域的联合都是我们最强大的力量 之源。我们国家在艺术与科学方面的创造层出不穷，成为独一无二的软实力之源，辐 射全球。 很少有哪些国家能够更好地驾驭未来的挑战，但我们必须愿意改变我们的方式，以适 应所处的新的世界环境。像英国这样开放民主的社会必须证明其已经准备好面对一个 更具竞争力的世界。我们必须展示 ：言论自由、思想自由和选择自由，以及由此而来 的创新自由，带来了内在优势 ；自由民主和自由市场仍然是人类社会与经济发展的最 佳模式。 历史证明，民主社会是一个维护开放，具有韧性的国际秩序最强有力的支持者。在这一 秩序中，全球各大机构证明了其在保护人权、应对大国间的紧张局势、解决争端、不 稳定和气候变化，并通过贸易和投资共享繁荣这几个方面发挥的作用。这一开放，具 有韧性的国际秩序也为我们的公民提供了最佳的安全保障。 i. 首相序言 3 要保持开放，我们也必须确保安全。保护我们的人民、我们的家园和我们的民主是任何 政府的首要职责，因此，我已启动自冷战结束以来最大规模的国防投资计划。该计划将 向我们在欧洲和其他各洲的盟友们证明他们始终能够在真正重要的时刻依靠英国。目 前英国的国防开支占国内生产总值的 2.2%，但我们将投入比先前计划的及北约开支承 诺更多的国防开支，推进现代化方案，拥抱比较网络和太空这些比较新近的领域，为 我们的武装部队配备尖端技术。我们将继续捍卫民族完整，抗击国家威胁，无论其形 式是非法资金，还是强制性经济措施、虚假情报、网络攻击、干预选举、甚至（在索 尔兹伯里神经毒剂攻击事发三年后）使用化学或其它大规模杀伤性武器。 曼彻斯特、伦敦和雷丁袭击案令人心痛地证实，无论是被伊斯兰教煽动、与北爱尔兰有 关还是受其它动机驱使，英国的恐怖主义威胁仍然很现实。我们的安全情报机构和执 法部门日以继夜地工作，将恐怖分子的袭击消灭于萌芽状态。自 2017 年起已经打断 了 28 起有计划的袭击。我们将在这个不可或缺的工作领域继续投资。2021-2022 年 我们将增加情报机构和“反恐警务”的资金并增聘两万名警员。我们将时刻保持警惕， 保护英国公民免遭严重的、有组织犯罪的伤害。 我们还将增添新的力量，例如 ：反恐行动中心和国家网络力量。我们从此次全球大流 行病汲取经验教训，将在政府核心处新建“情况中心”以增强我们的国家韧性，改善 对数据的使用，提升预测并应对未来危机的能力。此外，我们将在 2025 年前实现全 球最有效边境管理的目标，勇于创新，简化商旅人士往来的流程，提高英国的安全和 生物安全。 在数字时代，保持英国在科技领域的领先优势对我们的繁荣和竞争力来说将是不可或 缺的。我们旨在2030年前确保英国的科技超级强国地位。通过加大研发投入、加强全 球创新伙伴网络，提升国民技能，其中包括通过英国新推出的全球人才签证计划，吸引 全球最杰出、最聪明的人才移居英国。我们还将通过借助英国在数字技术方面的巨大优 势，吸引外来投资，将英国打造成全球服务、数字和数据枢纽，为长期繁荣奠定基础。 在 2021 年及以后，英国政府将以应对气候变化和生物多样性流失作为其第一国际要 务。最近，联合国安理会由我担任主席，举行了关于气候变化对和平与安全影响的首 次高级别会议。英国是首个设定 2050 年实现净零排放目标的发达经济体。我们将启 动一项前所未有的全新投资方案，通过资助英国在绿色技术方面的研发来推进英国绿 色工业革命“十点计划”，并借助英国国际气候资金帮助发展中国家。 建立外交、英联邦及发展事务部将助推我们的所有国际事务，将外交和发展相结合，从 而发挥更大的作用，处理气候变化和极端贫困之间的联系。英国将继续成为国际发展的 全球领袖，我们还将重新担负起承诺，在财政状况允许时，将国民总收入的 0.7% 投 入发展。另外，我们还将保持英国海外影响力的其它关键工具，例如 ：我们的全球外 交网络和英国文化教育协会，以推进女童教育以及宗教和媒体自由的倡导活动。 《整合评估》 4 英国 2021 年全球领导力 2021年将是英国领导力之年，通过出任七国集团主席并于6月举办康沃尔峰会、7月与 肯尼亚共同主持全球教育伙伴关系大会、11 月在格拉斯哥与意大利合作举办第二十六 届联合国气候变化会议，为英国未来十年的国际交往奠定基调。 2021 年，为英国皇家海军打造的迄今为止两艘最大的战舰之一，伊丽莎白女王号航空 母舰将率领英国和盟友的舰队进行近二十年来最具雄心的全球部署，出访地中海、中 东以及印太地区。伊丽莎白女王号航空母舰将展示我国与盟友及伙伴方（特别是美国） 之间的互操作性，展现我们在支持北约和国际海洋安全方面能够投入的尖端军事力量。 本次航空母舰的部署还将有助于英国政府加深英国与全球盟友和伙伴之间外交和繁荣 的纽带。 我对于英国在全球所处的地位和英国抓住未来机会的能力感到深度乐观。英国公民的 聪明才智，我们国家的联合王国体制，再加上我们的国际伙伴关系、现代化的武装力 量，以及全新的绿色议程，使我们在塑造未来世界的过程中满怀信心地展望未来。 i. 首相序言 5 首相对英国 2030 年的愿景 一个更加强大、更加安全、更加繁荣、更具韧性的联合王国 英国将成为民主主权的灯塔和全球最具影响力的国家之一，通过我们在国内外采取的 行动解决我国公民最关心的议题。 我们的联合王国将变得更加安全、更加繁荣，增长与机遇的成果将与全体英国公民共 享，无论这些公民是否居住在英国。 我们将从新冠疫情中恢复过来并重建得更好，经济强势复苏，在物理和数字世界中抵 御威胁和危害方面更加具备韧性。 我们将为面对更具竞争力的世界做好更充分的准备，捍卫我们的民主机构和经济，使 其免受国家威胁以及恐怖分子和有组织犯罪集团的伤害，同时支持科技创新，促进我 们国家的繁荣，提升战略优势。 以全球化的视野来解决问题并且分担负担的国家 英国将履行其作为联合国安理会常任理事国所赋予的责任，在维持国际秩序中发挥更 为积极的作用。在这个国际秩序中，开放的社会和经济体将继续蓬勃发展，并通过自 由贸易和全球增长分享繁荣的成果。 在由志同道合的国家和灵活形成的组织所构成的网络里，我们将处于核心地位，致力 于保护人权并维护全球规范。我们的影响力将因为更为强大的联盟和更为广泛的伙伴 关系而扩大。对于英国公民而言，最举足轻重的莫过于我们与美国的关系。 我们将继续是北约内部的主要欧洲盟友，共同应对威胁并将我们的资源用于欧洲 -大西 洋区域的集体安全，从而巩固我们的联盟。作为一个欧洲国家，我们将在相互尊重主 权，英国根据自身利益的需要在经济和政治上以不同方式自由行事的基础上，享受和 欧盟成员国建立起来的建设性和富有成效的关系。 到 2030 年，我们将作为欧洲的伙伴，以最广泛、最整合的方式深度参与印太地区事 务，支持互利贸易、共同的安全和价值观。我们将在非洲，特别是东非积极参与，与 尼日利亚这样的重要伙伴合作。此外，我们还将在中东和海湾地区建立以贸易、绿色 创新和科技协作为基础的繁荣发展的关系，支持在保障自身安全方面日益自给自足的、 更具韧性的这个地区。 《整合评估》 6 为我们的繁荣建立新的基础 到 2030 年，英国将继续在绿色技术方面引领世界发达经济体，作为我们在应对气候 变化和生物多样性丧失方面更广泛的国际领导力的组成部分。我们将坚定地走在实现 全球净零碳排放的道路上。与 20 世纪 90 年代水平相比，我们国家的碳排放已经至少 减少了 68%。我们还将至少已经保护了我国 30% 的土地和海洋，支持自然的恢复。 我们将被视为科技超级强国，在科研和创新的相关衡量指标中至少保持在全球第三，并 在人工智能等关键领域建立领先的优势。 我们将站在全球技术、网络、数字和数据监管的最前沿，保护我们自己和其他民主国 家，并加强英国作为全球服务、数字和数据枢纽的地位，最大限度地为英国人民提供 商业和就业机会。 英国将成为国际创新和人才的磁石，通过我们的积分制移民体系吸引海外最杰出，最聪 明的人才。英国全国各地都将享受到对研发、教育和文化机构长期投资所带来的好处。 适应更具竞争力的世界 ：我们整合的应对方式 英国将继续以其 ...
#  '« global britain », la grande-bretagne dans le monde à l’ère de la concurrence examen intégré de la sécurité, de la défense, du développement et de la politique étrangère i. avant-propos du premier ministre lorsque nous avons commencé l’examen intégré début 2020, nous n’aurions pas pu prévoir qu’un coronavirus allait déclencher ce qui deviendrait peut-être la plus grande crise internationale depuis la seconde guerre mondiale, avec des conséquences tragiques qui persisteraient pour des années à venir. la pandémie de covid-19 nous a rappelé que les menaces pour la sécurité et la mise à l’épreuve de la résilience nationale pouvaient prendre maintes formes. grâce à la force morale du peuple britannique et aux prodigieux efforts du nhs, le royaume-uni est en train de sortir de la pandémie avec un regain de détermination et d’optimisme. d’ores et déjà lancés sur la voie du redressement, nous sommes résolus à mieux reconstruire, en veillant à être plus forts, plus en sécurité et plus prospères qu’avant. toutefois, si nous voulons échapper aux effets pernicieux du virus, la course à la vaccination, et donc à la protection des personnes, ne doit pas s’arrêter aux frontières nationales. c’est pourquoi le royaume-uni s’est joint à d’autres pays dans l’initiative covax pour étendre cette campagne à toute la planète. ayant quitté l’union européenne, le royaume-uni entame un nouveau chapitre de son histoire. nous serons ouverts au monde, libres de tracer notre propre chemin, jouissant d’un réseau mondial d’amis et de partenaires, et capables de nouer des relations nouvelles et plus profondes. notre accord de commerce et de coopération avec l’union européenne nous donne la liberté de faire les choses différemment et mieux, tant sur le plan économique que politique. dans les années à venir, la souplesse et la rapidité d’action nous permettront de subvenir aux besoins de nos citoyens, améliorant notre prospérité et notre sécurité. à l’horizon 2030, ma vision pour le royaume-uni est très ambitieuse, sachant ce que notre pays est capable d’accomplir. l’union entre l’angleterre, l’écosse, le pays de galles et l’irlande du nord a fait ses preuves à maintes reprises, y compris dans cette pandémie. c’est notre plus grande source de force ici comme à l’étranger. notre pays regorge de créativité dans les arts et les sciences, sources intarissables d’un pouvoir d’influence unique qui se manifeste partout dans le monde. peu de nations sont mieux placées pour relever les défis à venir, mais nous devons être disposés à modifier notre approche et à nous adapter au monde nouveau qui émerge tout autour de nous. les sociétés ouvertes et démocratiques comme le royaume-uni doivent démontrer qu’elles sont à même d’affronter un monde plus concurrentiel. nous devons montrer que la liberté de s’exprimer, de penser et de choisir – et donc d’innover – offre un avantage intrinsèque ; et que la démocratie libérale et les marchés libres restent les meilleurs modèles pour le progrès socioéconomique de l’humanité. l’histoire a montré que les sociétés démocratiques étaient les plus ferventes alliées d’un ordre international ouvert et résilient, où les institutions mondiales prouvent qu’elles sont capables de protéger les droits de l’homme, de gérer les tensions entre les grandes puissances, de s’attaquer aux conflits, à l’instabilité et au changement climatique et de partager les richesses par le biais des échanges et de l’investissement. cet ordre international ouvert et résilient est à son tour le meilleur garant de la sécurité de nos propres citoyens. . i. avant-propos du premier ministre 3 pour être ouverts, nous devons aussi être en sécurité. la protection de son peuple, de son territoire et de sa démocratie étant le premier devoir de tout gouvernement, j’ai lancé le plus grand programme d’investissement dans la défense depuis la fin de la guerre froide. cela démontrera à nos alliés, en europe et au-delà, qu’ils peuvent toujours compter sur le royaume-uni lorsque l’ ...

# %% [markdown]
# This seems to work decently, though some long pdfs take a while.
# We can therefore run it on the whole dataset & this is probably a good time to make a single dataframe with all meta-data included. Pandas seems useful for this; basically, we do full outer joins of the meta-data. We can then add in the processed text, using the mapping table where necessary.

# %%
#Get the meta data from here
download_dirs = [ 
    r'C:\Users\siets009\OneDrive - Wageningen University & Research\Policy documents UK NL\Data\230524_GlobalWarming',
    r'C:\Users\siets009\\OneDrive - Wageningen University & Research\Policy documents UK NL\Data\230524_ClimateChange',
    r'C:\Users\siets009\OneDrive - Wageningen University & Research\Policy documents UK NL\Data\230524_Climate'
]

df = pd.DataFrame()
for prior_dir in download_dirs:
    with open(os.path.join(prior_dir, 'metadata.txt'), 'r') as f:
        meta = eval(f.read())
    df = pd.concat([df, pd.DataFrame.from_dict(meta, orient='index',
                                              columns = ['date', 'department', 'category', 'source_link', 'download_type']),
                   ])
df.reset_index(names = 'original_file', inplace=True)
print(df.shape)
df.head()
# Out:
# (25922, 6)
#                                        original_file              date  \
# 0  C:\Users\ajsie\OneDrive - Wageningen Universit...  15 November 2022
# 1  C:\Users\ajsie\OneDrive - Wageningen Universit...
# 2  C:\Users\ajsie\OneDrive - Wageningen Universit...
# 3  C:\Users\ajsie\OneDrive - Wageningen Universit...
# 4  C:\Users\ajsie\OneDrive - Wageningen Universit...
#
#                      department                 category  \
# 0  Government Property Function  guidance_and_regulation
# 1                                guidance_and_regulation
# 2                                guidance_and_regulation
# 3                                guidance_and_regulation
# 4                                guidance_and_regulation
#
#                                          source_link download_type
# 0  https://www.gov.uk/government/publications/gov...    linked_pdf
# 1  https://www.gov.uk/government/publications/ene...    linked_pdf
# 2  https://www.gov.uk/government/publications/ene...    linked_pdf
# 3  https://www.gov.uk/government/publications/ene...    linked_pdf
# 4  https://www.gov.uk/government/publications/ene...    linked_pdf

# %%
df['department'].value_counts()[:10]
# Out:
# Planning Inspectorate                                    2597
#                                                          2244
# Department of Energy & Climate Change                    2036
# Environment Agency                                       1360
# Department for Environment, Food & Rural Affairs         1316
# Foreign & Commonwealth Office                            1130
# Prime Minister's Office, 10 Downing Street               1001
# Department for Energy Security and Net Zero               884
# Foreign, Commonwealth & Development Office                864
# Department for Business, Energy & Industrial Strategy     849
# Name: department, dtype: int64

# %%
with open(r'C:\Users\siets009\OneDrive - Wageningen University & Research\Policy scraper UK NL\Data\230524_ConvertedPDFs\mappingToPDFs.pickle', 'rb') as f:
    mapping = pickle.load(f)


df['txt_file'] = None

for i in mapping:
    df.loc[df['original_file'] == i[0], 'txt_file'] = i[1]
df.head()
# Out:
#                                        original_file              date  \
# 0  C:\Users\ajsie\OneDrive - Wageningen Universit...  15 November 2022
# 1  C:\Users\ajsie\OneDrive - Wageningen Universit...
# 2  C:\Users\ajsie\OneDrive - Wageningen Universit...
# 3  C:\Users\ajsie\OneDrive - Wageningen Universit...
# 4  C:\Users\ajsie\OneDrive - Wageningen Universit...
#
#                      department                 category  \
# 0  Government Property Function  guidance_and_regulation
# 1                                guidance_and_regulation
# 2                                guidance_and_regulation
# 3                                guidance_and_regulation
# 4                                guidance_and_regulation
#
#                                          source_link download_type txt_file
# 0  https://www.gov.uk/government/publications/gov...    linked_pdf     None
# 1  https://www.gov.uk/government/publications/ene...    linked_pdf     None
# 2  https://www.gov.uk/government/publications/ene...    linked_pdf     None
# 3  https://www.gov.uk/government/publications/ene...    linked_pdf     None
# 4  https://www.gov.uk/government/publications/ene...    linked_pdf     None

# %%
len(df['txt_file'].unique())
# Out:
# 6560

# %%
print(len(mapping))
# Out:
# 11111
